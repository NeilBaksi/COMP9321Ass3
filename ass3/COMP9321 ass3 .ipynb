# %%
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
from math import *

df = pd.read_csv('crimes.csv')

df.index+=1

df = df.drop('Subcategory', axis=1)

df.rename(columns={'Offence category': 'Offence_category'}, inplace=True)

df = df[:-4]

#list of unique offences in the table
#count = 1
#for i in df.Offence_category.unique():
#    print(count, i)
#    count+=1

#list of unique LGAs
#count = 1
#for lga in df.LGA.unique():
#    print(count, lga)
#    count+=1

df = df.groupby(['LGA','Offence_category']).sum().reset_index()
df.index+=1


#to select required columns (years: Jan 2007 - Dec 2011)
def select_cols_for_ml():
    cols = []
    cols.append(0)
    cols.append(1)
    for i in range(146, 218):
        cols.append(i)
    return cols

#select rqd cols (years: Jan 2007 - Dec 2011)
df1 = df.iloc[:, select_cols_for_ml()]
df1.head(200)

df1 = df1.loc[df['Offence_category'] == 'Assault']

def select_cols_for_training():
    cols = []
    #cols.append(0)
    for i in range(2, 62):
        cols.append(i)
    return cols


#ML


df1 = shuffle(df1)
#all values from 2007 - 2011 for training
assault_x = df1.iloc[:, select_cols_for_training()].values
#values from jan 2012 as target to be predicted
assault_y = df1[['Jan 2012']].values



# Split the dataset in train and test data
# A random permutation, to split the data randomly

split_point = int(len(assault_x) * 0.75)
assault_x_train = assault_x[:split_point]
assault_y_train = assault_y[:split_point]
assault_x_test = assault_x[split_point:]
assault_y_test = assault_y[split_point:]

model = linear_model.LinearRegression()

model.fit(assault_x_train, assault_y_train)

y_pred = model.predict(assault_x_test)

for i in range(len(assault_y_test)):
        print("Expected:", assault_y_test[i], "Predicted:", y_pred[i])

# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(assault_y_test, y_pred))

#df2 = pd.DataFrame(
#{'Actual_assault_rate': assault_y_test,
# 'Prediction': y_pred     
#})

#df2.plot()
# Out:
# Expected: [40.] Predicted: [41.22720312]
# Expected: [13.] Predicted: [25.65193979]
# Expected: [0.] Predicted: [1.12014225]
# Expected: [204.] Predicted: [217.53841363]
# Expected: [173.] Predicted: [208.3723749]
# Expected: [2.] Predicted: [17.84802856]
# Expected: [19.] Predicted: [18.19868571]
# Expected: [13.] Predicted: [30.84198321]
# Expected: [10.] Predicted: [17.68205863]
# Expected: [1.] Predicted: [-0.98180697]
# Expected: [16.] Predicted: [18.045846]
# Expected: [20.] Predicted: [23.96441307]
# Expected: [4.] Predicted: [0.34696575]
# Expected: [141.] Predicted: [135.05194895]
# Expected: [119.] Predicted: [119.02647864]
# Expected: [8.] Predicted: [3.26361127]
# Expected: [5.] Predicted: [-2.48017072]
# Expected: [2.] Predicted: [1.87982711]
# Expected: [49.] Predicted: [31.83424536]
# Expected: [48.] Predicted: [45.11781179]
# Expected: [51.] Predicted: [64.7310125]
# Expected: [8.] Predicted: [5.33089473]
# Expected: [8.] Predicted: [11.77599492]
# Expected: [41.] Predicted: [48.45428541]
# Expected: [20.] Predicted: [22.6127953]
# Expected: [62.] Predicted: [33.11281786]
# Expected: [6.] Predicted: [2.83789258]
# Expected: [104.] Predicted: [116.5151104]
# Expected: [17.] Predicted: [18.02670709]
# Expected: [72.] Predicted: [78.02152117]
# Expected: [5.] Predicted: [6.61453132]
# Expected: [70.] Predicted: [68.74035758]
# Expected: [26.] Predicted: [20.51560564]
# Expected: [1.] Predicted: [1.446671]
# Expected: [30.] Predicted: [38.32410618]
# Expected: [61.] Predicted: [61.31450937]
# Expected: [4.] Predicted: [13.1242008]
# Expected: [6.] Predicted: [10.58457345]
# Expected: [3.] Predicted: [19.38128173]
# Mean squared error: 114.55
